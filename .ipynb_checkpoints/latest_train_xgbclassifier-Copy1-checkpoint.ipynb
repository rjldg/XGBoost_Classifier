# %%
import pandas as pd
import numpy as np
import os
from glob import glob
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from xgboost import XGBClassifier
from skopt import BayesSearchCV
from skopt.space import Real, Integer
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, log_loss
import joblib

# %%
# Function to load CSV files from a directory and assign labels
def load_csvs_from_folder(folder_path, label):
    csv_files = glob(os.path.join(folder_path, '*.csv'))
    dataframes = []
    for file in csv_files:
        df = pd.read_csv(file)
        df['Class'] = label  # Assign class label (0 for animal, 1 for plant)
        dataframes.append(df)
    return pd.concat(dataframes, ignore_index=True)

# %%
# Load data from two directories
animal_oils_folder = 'readings/Animal'
plant_oils_folder = 'readings/Plant'

# %%
# Load data for both classes
animal_oils_data = load_csvs_from_folder(animal_oils_folder, label=0)
plant_oils_data = load_csvs_from_folder(plant_oils_folder, label=1)

# %%
# Combine both datasets into a single DataFrame
df = pd.concat([animal_oils_data, plant_oils_data], ignore_index=True)

# %%
# Check the structure of the combined data
print(df.head())
print(df['Class'].value_counts())
# Out:
#   MQ2  MQ3  MQ4  MQ5  MQ6  MQ7  MQ8  MQ9  MQ135  MQ137  Class
# 0  58  118   79   34  145  146  315  168    113    191      0
# 1  57  118   79   34  145  146  315  168    114    190      0
# 2  59  118   80   35  146  147  316  169    113    191      0
# 3  58  118   79   34  146  146  316  169    114    191      0
# 4  59  118   79   35  146  146  315  169    114    190      0
# Class
# 1    117843
# 0    114018
# Name: count, dtype: int64

# %%
# Split features (X) and target (y)
X = df.drop(columns='Class')
y = df['Class']

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, stratify=y, random_state=32)

# %%
# More preprocessing measures
print(X_train.head())  # Quick view of the data
print(X_train.info())  # Check data types
print(X_train.isnull().sum())  # Check for null values
# Out:
#        MQ2  MQ3  MQ4  MQ5  MQ6  MQ7  MQ8  MQ9  MQ135  MQ137
# 43644   54  127   70   36  129  208  349  193    118    189
# 61307   59  119   79   35  145  157  314  170    113    190
# 123973  51  138   68   33  119  200  334  177    110    187
# 151452  59  107   81   34  147  158  318  166    117    185
# 82426   62  112   83   35  150  159  315  168    114    190
# <class 'pandas.core.frame.DataFrame'>
# Index: 185488 entries, 43644 to 156135
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   MQ2     185488 non-null  object
#  1   MQ3     185488 non-null  int64
#  2   MQ4     185488 non-null  int64
#  3   MQ5     185488 non-null  int64
#  4   MQ6     185488 non-null  int64
#  5   MQ7     185488 non-null  int64
#  6   MQ8     185488 non-null  int64
#  7   MQ9     185488 non-null  int64
#  8   MQ135   185488 non-null  int64
#  9   MQ137   185488 non-null  int64
# dtypes: int64(9), object(1)
# memory usage: 15.6+ MB
# None
# MQ2      0
# MQ3      0
# MQ4      0
# MQ5      0
# MQ6      0
# MQ7      0
# MQ8      0
# MQ9      0
# MQ135    0
# MQ137    0
# dtype: int64

# %%
# Checking for non-numeric data
invalid_rows = X_train.applymap(lambda x: isinstance(x, str) and not x.isnumeric())
print(X_train[invalid_rows.any(axis=1)])  # Show rows with non-numeric data
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_24940\2121600327.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   invalid_rows = X_train.applymap(lambda x: isinstance(x, str) and not x.isnumeric())
# Empty DataFrame
# Columns: [MQ2, MQ3, MQ4, MQ5, MQ6, MQ7, MQ8, MQ9, MQ135, MQ137]
# Index: []

# %%
# Data cleaning (as needed)

'''
# Replace invalid entries with NaN
X_train = X_train.replace({r'[^\d.]': np.nan}, regex=True)

# Convert the column to numeric, coercing errors to NaN
X_train = X_train.apply(pd.to_numeric, errors='coerce')

# Drop rows with NaN (optional, depending on your handling strategy)
X_train = X_train.dropna()
'''

# %%
# Define the pipeline with PCA and XGBClassifier
pipeline = Pipeline([
    ('pca', PCA()),  # Principal Component Analysis
    ('clf', XGBClassifier(random_state=32, eval_metric='logloss'))  # XGBoost Classifier
])

# %%
# To handle unformatted values
X_train = X_train.applymap(lambda x: x.replace('\x18', '') if isinstance(x, str) else x)
X_test = X_test.applymap(lambda x: x.replace('\x18', '') if isinstance(x, str) else x)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_24940\3207247740.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   X_train = X_train.applymap(lambda x: x.replace('\x18', '') if isinstance(x, str) else x)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_24940\3207247740.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   X_test = X_test.applymap(lambda x: x.replace('\x18', '') if isinstance(x, str) else x)

# %%
# Define the search space for Bayesian optimization
search_space = {
    'clf__max_depth': Integer(2, 8),
    'clf__learning_rate': Real(0.001, 1.0, prior='log-uniform'),
    'clf__subsample': Real(0.5, 1.0),
    'clf__colsample_bytree': Real(0.5, 1.0),
    'clf__colsample_bylevel': Real(0.5, 1.0),
    'clf__colsample_bynode': Real(0.5, 1.0),
    'clf__reg_alpha': Real(0.0, 10.0),
    'clf__reg_lambda': Real(0.0, 10.0),
    'clf__gamma': Real(0.0, 10.0),
    'pca__n_components': Integer(2, min(X_train.shape[1],9))
}

# Use BayesSearchCV for hyperparameter optimization
opt = BayesSearchCV(pipeline, search_space, cv=5, n_iter=12, scoring='roc_auc_ovr', random_state=32)
opt.fit(X_train, y_train)
# Out:
# BayesSearchCV(cv=5,
#               estimator=Pipeline(steps=[('pca', PCA()),
#                                         ('clf',
#                                          XGBClassifier(base_score=None,
#                                                        booster=None,
#                                                        callbacks=None,
#                                                        colsample_bylevel=None,
#                                                        colsample_bynode=None,
#                                                        colsample_bytree=None,
#                                                        device=None,
#                                                        early_stopping_rounds=None,
#                                                        enable_categorical=False,
#                                                        eval_metric='logloss',
#                                                        feature_types=None,
#                                                        gamma=None,
#                                                        grow_policy=None,
#                                                        importance_type=None,
#                                                        inter...
#                              'clf__max_depth': Integer(low=2, high=8, prior='uniform', transform='normalize'),
#                              'clf__reg_alpha': Real(low=0.0, high=10.0, prior='uniform', transform='normalize'),
#                              'clf__reg_lambda': Real(low=0.0, high=10.0, prior='uniform', transform='normalize'),
#                              'clf__subsample': Real(low=0.5, high=1.0, prior='uniform', transform='normalize'),
#                              'pca__n_components': Integer(low=2, high=9, prior='uniform', transform='normalize')})

# %%
# Best model and its performance
print("Best Estimator:", opt.best_estimator_)
print("Best Score on Training Data:", opt.best_score_)
print("Score on Test Data:", opt.score(X_test, y_test))
# Out:
# Best Estimator: Pipeline(steps=[('pca', PCA(n_components=9)),
#                 ('clf',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=0.9204908270084542,
#                                colsample_bynode=0.5468515518275134,
#                                colsample_bytree=0.725177309421997, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric='logloss',
#                                feature_types=None, gamma=8.640214170740494,
#                                grow...one, importance_type=None,
#                                interaction_constraints=None,
#                                learning_rate=0.6195193522411349, max_bin=None,
#                                max_cat_threshold=None, max_cat_to_onehot=None,
#                                max_delta_step=None, max_depth=7,
#                                max_leaves=None, min_child_weight=None,
#                                missing=nan, monotone_constraints=None,
#                                multi_strategy=None, n_estimators=None,
#                                n_jobs=None, num_parallel_tree=None,
#                                random_state=32, ...))])
# Best Score on Training Data: 0.9997262084255988
# Score on Test Data: 0.9998747291640768

# %%
# Predictions and probabilities
y_pred = opt.predict(X_test)
y_proba = opt.predict_proba(X_test)

# %%
# Evaluate accuracy and log loss
accuracy = accuracy_score(y_test, y_pred)
logloss = log_loss(y_test, y_proba)
print(f"Test Accuracy: {accuracy}")
print(f"Test Log Loss: {logloss}")
# Out:
# Test Accuracy: 0.9951696030017467
# Test Log Loss: 0.018621870358526287

# %%
# Save the best estimator
model_save_path = 'models/rev4_dec15_xgboost_oil_classifier_model.joblib'
joblib.dump(opt.best_estimator_, model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to models/rev4_dec15_xgboost_oil_classifier_model.joblib

# %%
# Save the PCA transformer separately
# pca_save_path = 'models/new_pca_transformer.joblib'
# best_pca = opt.best_estimator_.named_steps['pca']
# joblib.dump(best_pca, pca_save_path)
# print(f"PCA transformer saved to {pca_save_path}")

# %%
# Feature importance from XGBoost
feature_importance = opt.best_estimator_.named_steps['clf'].feature_importances_
plt.figure(figsize=(10, 6))
plt.bar(range(len(feature_importance)), feature_importance)
plt.title('Feature Importance from XGBoost')
plt.xlabel('Features')
plt.ylabel('Importance')
plt.show()

# %%
# PCA Visualization
pca = opt.best_estimator_.named_steps['pca']
#X_train_pca = pca.transform(X_train)
#X_test_pca = pca.transform(X_test)
X_train_pca = best_pca.transform(X_train)
X_test_pca = best_pca.transform(X_test)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X_train_pca[:, 0], X_train_pca[:, 1], c=y_train, cmap='coolwarm', alpha=0.5, label='Training')
plt.scatter(X_test_pca[:, 0], X_test_pca[:, 1], c=y_test, cmap='coolwarm', marker='x', alpha=0.8, label='Testing')
plt.title('PCA Plot')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()
